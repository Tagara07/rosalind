# %% [markdown]
# Combing Through the Haystack

# %%
import jun_function as jf

# %%
with open(r'./data/09_rosalind_subs.txt', 'r') as f:
    file = f.readlines()
    s = file[0].replace('\n', '')
    t = file[1].replace('\n', '')
    f.close()

# %%
idx_ls = []

if len(s) > len(t):
    for i in range(len(s) - len(t) + 1):
        if s[i:i+len(t)] == t:
            idx_ls.append(str(i+1)) 

idx_str = ' '.join(idx_ls)

jf.gen_txt(str(idx_str))
