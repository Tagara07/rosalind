# %% [markdown]
# Strings and Lists

# %%
with open(r'./data/03_rosalind_ini3.txt') as f:
    file = f.readlines()
    str = file[0]
    num_ls = file[1].replace('\n', '').split(' ')
    a = int(num_ls[0])
    b = int(num_ls[1])
    c = int(num_ls[2])
    d = int(num_ls[3])
    f.close()

# %%
def str_slice(str, a, b, c, d):
    print(f'{str[a:b+1]} {str[c:d+1]}')

# %%
str_slice(str, a, b, c, d)
# Out:
# Bombina dentata
